# %%
from qiskit import IBMQ, QuantumCircuit, Aer
from qiskit.utils import QuantumInstance
from main_v2 import *

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-csic', group='internal', project='iff-csic')
backend  = provider.get_backend('ibm_lagos')
noise_model = NoiseModel.from_backend(backend)
# noise_model = decoherence_noise(T1=5e3, T2=200e3)
quantum_instance = QuantumInstance( Aer.get_backend('aer_simulator'), shots=2**13 )
# quantum_instance = QuantumInstance( backend, shots=2**13 )
# Out:
# Device reported a gate error parameter greater than maximum allowed value (1.000000 > 0.800000). Truncating to maximum value.
# Device model returned a depolarizing error parameter greater than maximum allowed value (1.067017 > 1.066667). Truncating to maximum value.
# Device reported a gate error parameter greater than maximum allowed value (1.000000 > 0.800000). Truncating to maximum value.
# Device model returned a depolarizing error parameter greater than maximum allowed value (1.067059 > 1.066667). Truncating to maximum value.

# %%
n = 1
p = 2

# %%
mpt = measurement_process_tomography( n, p)
circuits = mpt.circuits()
circuits[0].draw(output='mpl')

# %%
results = quantum_instance.execute(circuits)

# %%
operators = mpt.fit( results, circuits )

# %%
operators
# Out:
# [[array([[ 9.99988179e-01+0.00000000e+00j, -8.28741819e-04+5.98986900e-04j, -8.28741819e-04-5.98986900e-04j,  1.04806198e-06+0.00000000e+00j],
#          [ 9.91203648e-04-2.47376975e-03j,  8.90539347e-04-1.65294361e-03j, -2.30457035e-06+1.45476898e-06j, -1.72765177e-06+8.36162571e-07j],
#          [ 9.91203648e-04+2.47376975e-03j, -2.30457035e-06-1.45476898e-06j,  8.90539347e-04+1.65294361e-03j, -1.72765177e-06-8.36162571e-07j],
#          [ 7.10393921e-06+0.00000000e+00j,  4.97169536e-06+5.65077337e-07j,  4.97169536e-06-5.65077337e-07j,  3.52545612e-06+0.00000000e+00j]]),
#   array([[ 3.00532517e-07+0.00000000e+00j,  1.81237507e-07+4.57336746e-08j,  1.81237507e-07-4.57336746e-08j,  5.42064563e-06+0.00000000e+00j],
#          [-2.94184753e-07+8.59379546e-07j, -4.93787493e-05+4.14842317e-05j, -1.65427051e-06+2.10438619e-06j,  2.07444405e-06+2.31859462e-03j],
#          [-2.94184753e-07-8.59379546e-07j, -1.65427051e-06-2.10438619e-06j, -4.93787493e-05-4.14842317e-05j,  2.07444405e-06-2.31859462e-03j],
#          [ 3.68392616e-06+0.00000000e+00j,  8.23322948e-04-5.99101827e-04j,  8.23322948e-04+5.99101827e-04j,  9.99990739e-01+0.00000000e+00j]])],
#  [array([[ 9.99983604e-01+0.00000000e+00j, -1.59335767e-05-1.51562198e-03j, -1.59335767e-05+1.51562198e-03j,  2.30616909e-06+0.00000000e+00j],
#          [-1.54805159e-04-2.75377243e-03j, -1.71814471e-03+9.46990402e-04j,  4.17452505e-06-1.89117685e-07j, -1.41474880e-06-2.61668053e-06j],
#          [-1.54805159e-04+2.75377243e-03j,  4.17452505e-06+1.89117685e-07j, -1.71814471e-03-9.46990402e-04j, -1.41474880e-06+2.61668053e-06j],
#          [ 7.60871273e-06+0.00000000e+00j, -2.34192507e-06-4.87487691e-06j, -2.34192507e-06+4.87487691e-06j,  3.86741355e-06+0.00000000e+00j]]),
#   array([[ 1.93563886e-06+0.00000000e+00j, -3.91477538e-06-1.68482955e-06j, -3.91477538e-06+1.68482955e-06j,  1.86020790e-05+0.00000000e+00j],
#          [-1.92593691e-06-1.32970217e-06j,  5.21092567e-04+1.49271254e-04j,  2.98316435e-07+1.80664643e-06j, -2.81088519e-03-2.12204465e-03j],
#          [-1.92593691e-06+1.32970217e-06j,  2.98316435e-07-1.80664643e-06j,  5.21092567e-04-1.49271254e-04j, -2.81088519e-03+2.12204465e-03j],
#          [ 5.35019176e-06+0.00000000e+00j,  2.23531174e-05+1.52215497e-03j,  2.23531174e-05-1.52215497e-03j,  9.99976725e-01+0.00000000e+00j]])]]

# %%
counts = []
for qc in circuits:
    counts.append(  dict2array(  results.get_counts(qc), 6 )  )
counts_1 = np.array( counts )

# %%
qc = QuantumCircuit(1,1)
qc.measure(0,0)
qc.reset(0)
qc.draw(output='mpl')
qc.x(0).c_if(qc.cregs[0],1)
qc.draw(output='mpl')

# %%
mpt_2 = measurement_process_tomography( n, p )
circuits_2 = mpt_2.circuits(qc)
circuits_2[0].draw(output='mpl',cregbundle=False)

# %%
results_2 = quantum_instance.execute(circuits_2)

# %%
operators_2 = mpt.fit( results_2, circuits_2 )

# %%
operators_2
# Out:
# [[array([[ 9.99959994e-01+0.00000000e+00j,  3.41946328e-03-1.64352081e-03j,  3.41946328e-03+1.64352081e-03j,  1.43989009e-05+0.00000000e+00j],
#          [-2.65344632e-03+1.03493759e-03j,  1.63808217e-03-1.36932515e-04j, -1.07743964e-05-8.21072932e-07j,  5.82538042e-06+2.22427980e-06j],
#          [-2.65344632e-03-1.03493759e-03j, -1.07743964e-05+8.21072932e-07j,  1.63808217e-03+1.36932515e-04j,  5.82538042e-06-2.22427980e-06j],
#          [ 8.11245955e-06+0.00000000e+00j, -4.48850870e-06-1.33171542e-06j, -4.48850870e-06+1.33171542e-06j,  2.70254270e-06+0.00000000e+00j]]),
#   array([[ 1.47300028e-06+0.00000000e+00j, -8.83422309e-07+1.77163628e-07j, -8.83422309e-07-1.77163628e-07j,  6.97877131e-07+0.00000000e+00j],
#          [-3.77856564e-06-2.47031101e-06j, -1.10772462e-05+1.61047265e-04j,  2.95342190e-06+3.02444471e-06j, -3.41204675e-04-1.91217508e-04j],
#          [-3.77856564e-06+2.47031101e-06j,  2.95342190e-06-3.02444471e-06j, -1.10772462e-05-1.61047265e-04j, -3.41204675e-04+1.91217508e-04j],
#          [ 2.85602733e-05+0.00000000e+00j, -3.41441507e-03+1.64462623e-03j, -3.41441507e-03-1.64462623e-03j,  9.99984061e-01+0.00000000e+00j]])],
#  [array([[ 9.99975059e-01+0.00000000e+00j, -4.70849713e-05+9.54708506e-05j, -4.70849713e-05-9.54708506e-05j,  7.29478813e-07+0.00000000e+00j],
#          [-2.31858158e-03-2.53177742e-03j,  2.02210305e-03+3.27060648e-03j, -1.62345406e-07+3.97226775e-07j,  2.31577474e-07-3.61489550e-07j],
#          [-2.31858158e-03+2.53177742e-03j, -1.62345406e-07-3.97226775e-07j,  2.02210305e-03-3.27060648e-03j,  2.31577474e-07+3.61489550e-07j],
#          [ 1.17933494e-05+0.00000000e+00j, -1.29720204e-05-2.46494217e-06j, -1.29720204e-05+2.46494217e-06j,  1.47877407e-05+0.00000000e+00j]]),
#   array([[ 2.36411111e-06+0.00000000e+00j,  2.44561335e-07+7.88270747e-07j,  2.44561335e-07-7.88270747e-07j,  2.98101796e-07+0.00000000e+00j],
#          [-1.13423208e-06+3.42456456e-06j,  1.16423076e-05+2.48538680e-04j,  9.18646155e-07+8.14359173e-07j,  9.95472193e-05+6.04088353e-06j],
#          [-1.13423208e-06-3.42456456e-06j,  9.18646155e-07-8.14359173e-07j,  1.16423076e-05-2.48538680e-04j,  9.95472193e-05-6.04088353e-06j],
#          [ 7.30262904e-06+0.00000000e+00j,  5.90691921e-05-9.32800531e-05j,  5.90691921e-05+9.32800531e-05j,  9.99987666e-01+0.00000000e+00j]])]]
