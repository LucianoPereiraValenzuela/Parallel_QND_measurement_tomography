# %%
import sys
sys.path.append('../../')

import numpy as np
import matplotlib.pyplot as plt
from utils_plots import *

# %%
results_mc = np.load( 'data/data_mc.npy', allow_pickle=True )

# %%
chois = [ x[0] for x in results_mc   ]
povms = [ x[1] for x in results_mc   ]
quans = [ x[2] for x in results_mc   ]

# %%
Plot_Chois( np.mean( chois, 0 ), np.std( chois, axis=0 )  )
# Out:
# [<Axes3DSubplot:>, <Axes3DSubplot:>]

# %%
np.mean(quans, axis=0), np.std( quans, axis=0 )
# Out:
# (array([0.96874432, 0.9390533 , 0.96727687]),
#  array([0.00648873, 0.00936418, 0.01037396]))
