# %%
import numpy as np
import matplotlib.pyplot as plt
from main_figures import Plot_Chois, set_ticks

# %%
data = np.load('data_final_tomography.npy', allow_pickle=True)[0]

# %%
Choi_single_device_mean = data['single']['Choi_device_mean']
Choi_single_device_std= data['single']['Choi_device_std']
Choi_double_device_mean = data['double']['Choi_device_mean']
Choi_double_device_std= data['double']['Choi_device_std']

# %%
pos_label = [3.2, 4, 0.12]
Labels = [ r'$|\bar\Upsilon_0|$', r'$|\bar\Upsilon_1|$'  ]
pos_ticks = [0,1,2,3]
x_ticks = [r'$|00\rangle$', r'$|01\rangle$', r'$|10\rangle$',r'$|11\rangle$']
y_ticks = [r'$\langle 00|$', r'$\langle 01|$', r'$\langle 10|$', r'$\langle 11|$']
axes = Plot_Chois(Choi_single_device_mean, Choi_single_device_std, shape=(2,1) )
axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
plt.savefig('choi_single.svg', bbox_inches='tight' )

# %%
chois_q2_mean = data['single']['chois_mean'][2]
chois_q2_std = data['single']['chois_std'][2]
chois_q5_mean = data['single']['chois_mean'][5]
chois_q5_std = data['single']['chois_std'][5]

# %%
pos_label = [3.2, 4, 0.12]
Labels = [ r'$|\Upsilon_0^2|$', r'$|\Upsilon_1^2|$'  ]
pos_ticks = [0,1,2,3]
x_ticks = [r'$|00\rangle$', r'$|01\rangle$', r'$|10\rangle$',r'$|11\rangle$']
y_ticks = [r'$\langle 00|$', r'$\langle 01|$', r'$\langle 10|$', r'$\langle 11|$']
axes = Plot_Chois(chois_q2_mean, chois_q2_std, shape=(2,1)  )
axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
plt.savefig('choi_single_q2.svg', bbox_inches='tight' )

# %%
pos_label = [3.2, 4, 0.12]
Labels = [ r'$|\Upsilon_0^5|$', r'$|\Upsilon_1^5|$'  ]
pos_ticks = [0,1,2,3]
x_ticks = [r'$|00\rangle$', r'$|01\rangle$', r'$|10\rangle$',r'$|11\rangle$']
y_ticks = [r'$\langle 00|$', r'$\langle 01|$', r'$\langle 10|$', r'$\langle 11|$']
axes = Plot_Chois(chois_q5_mean, chois_q5_std, shape=(2,1)  )
axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
plt.savefig('choi_single_q5.svg', bbox_inches='tight' )

# %%
pos_label = [16., 16, 0.13]
Labels = [ r'$|\bar\Upsilon_{00}|$', r'$|\bar\Upsilon_{01}|$', r'$|\bar\Upsilon_{10}|$', r'$|\bar\Upsilon_{11}|$' ]
pos_ticks = [0,5,10,15]
x_ticks = [r'$|0000\rangle$', r'$|0101\rangle$', r'$|1010\rangle$',r'$|1111\rangle$']
y_ticks = [r'$\langle 0000|$', r'$\langle 0101|$', r'$\langle 1010|$', r'$\langle 1111|$']
axes = Plot_Chois(Choi_double_device_mean, Choi_double_device_std, shape=(2,2) )
axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
plt.savefig('choi_double.svg', bbox_inches='tight' )

# %%
data2 = np.load('data_final_mar.npy', allow_pickle=True)[0]

# %%
chois1 = data2['mar']['chois']
chois1_std = data2['mar']['chois_std']
q1 = data2['mar']['quantities']
q1_std = data2['mar']['quantities_std']
q1, q1_std
# Out:
# (array([0.95797579, 0.8735964 , 0.90921437]),
#  array([0.00093349, 0.00179027, 0.00148782]))

# %%
chois2 = data2['standard']['chois']
chois2_std = data2['standard']['chois_std']
q2 = data2['standard']['quantities']
q2_std = data2['standard']['quantities_std']
q2, q2_std
# Out:
# (array([0.95909367, 0.90981695, 0.95355943]),
#  array([0.000953  , 0.00160002, 0.00144803]))

# %%
pos_label = [3.2, 4, 0.125]
Labels = [ r'$|\Upsilon_0|$', r'$|\Upsilon_1|$'  ]
pos_ticks = [0,1,2,3]
x_ticks = [r'$|00\rangle$', r'$|01\rangle$', r'$|10\rangle$',r'$|11\rangle$']
y_ticks = [r'$\langle 00|$', r'$\langle 01|$', r'$\langle 10|$', r'$\langle 11|$']

# %%
axes = Plot_Chois(chois1, chois1_std )
axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
plt.savefig('choi_single_mar.svg', bbox_inches='tight' )

# %%
axes = Plot_Chois(chois2, chois2_std )
axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
plt.savefig('choi_single_std.svg', bbox_inches='tight' )

# %%
Choi_single_mean = data['single']['chois_mean']
Choi_single_std= data['single']['chois_std']
Choi_double_mean = data['double']['chois_mean']
Choi_double_std= data['double']['chois_std']

# %%
pos_label = [3.2, 4, 0.12]
pos_ticks = [0,1,2,3]
x_ticks = [r'$|00\rangle$', r'$|01\rangle$', r'$|10\rangle$',r'$|11\rangle$']
y_ticks = [r'$\langle 00|$', r'$\langle 01|$', r'$\langle 10|$', r'$\langle 11|$']
for j in range(7):
    Labels = [ r'$|\Upsilon_0^{}|$'.format(j), r'$|\Upsilon_1^{}|$'.format(j)  ]
    axes = Plot_Chois(Choi_single_mean[j], Choi_single_std[j], shape=(1,2)  )
    axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
    plt.savefig('choi_single_q{}.pdf'.format(j), bbox_inches='tight' )

# %%
pairs = [ [(1,3), (4,5)], [(3,5),(0,1)], [(1,2),(5,6)] ]

# %%
Labels_all = [ [ [r'$|\Upsilon^{13}_{00}|$',r'$|\Upsilon^{13}_{01}|$',r'$|\Upsilon^{13}_{10}|$',r'$|\Upsilon^{13}_{11}|$'],
             [r'$|\Upsilon^{45}_{00}|$',r'$|\Upsilon^{45}_{01}|$',r'$|\Upsilon^{45}_{10}|$',r'$|\Upsilon^{45}_{11}|$'] ],
           [ [r'$|\Upsilon^{35}_{00}|$',r'$|\Upsilon^{35}_{01}|$',r'$|\Upsilon^{35}_{10}|$',r'$|\Upsilon^{35}_{11}|$'],
             [r'$|\Upsilon^{01}_{00}|$',r'$|\Upsilon^{01}_{01}|$',r'$|\Upsilon^{01}_{10}|$',r'$|\Upsilon^{01}_{11}|$'] ],
           [ [r'$|\Upsilon^{12}_{00}|$',r'$|\Upsilon^{12}_{01}|$',r'$|\Upsilon^{12}_{10}|$',r'$|\Upsilon^{12}_{11}|$'],
             [r'$|\Upsilon^{56}_{00}|$',r'$|\Upsilon^{56}_{01}|$',r'$|\Upsilon^{56}_{10}|$',r'$|\Upsilon^{56}_{11}|$'] ]    
              ]

# %%
pos_label = [16., 14, 0.1385]
pos_ticks = [0,5,10,15]
x_ticks = [r'$|0000\rangle$', r'$|0101\rangle$', r'$|1010\rangle$',r'$|1111\rangle$']
y_ticks = [r'$\langle 0000|$', r'$\langle 0101|$', r'$\langle 1010|$', r'$\langle 1111|$']
for j in range(3):
    for k in range(2):
        Labels = Labels_all[j][k]
        axes = Plot_Chois(Choi_double_mean[j,k], Choi_double_std[j,k], shape=(2,2) )
        axes = set_ticks( axes, pos_ticks, x_ticks, pos_ticks, y_ticks, pos_label, Labels )
        plt.savefig( 'choi_double_g{}p{}.pdf'.format(j,k), bbox_inches='tight' )
